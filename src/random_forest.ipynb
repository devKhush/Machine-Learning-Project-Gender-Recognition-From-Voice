# %%
import pandas as pd
import numpy as np
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../assests/scaled_voice_data.csv')
x = df.drop('gender', axis=1)
y = df['gender']
le = LabelEncoder()
Y_encoded = le.fit_transform(y)
X_train, X_test, y_train, y_test = train_test_split(x, Y_encoded, test_size = 0.2, random_state = 100)

# %%
df.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      kurt  \
# 0  0.053833  0.182412 -0.043344 -0.211354  0.539997  0.538854 -0.240888
# 1 -1.948336  1.299573 -2.059818 -1.855442 -0.519379  1.824196  0.163259
# 2  0.646042  0.495259  0.871554  0.640148  1.145548 -0.095419 -0.201828
# 3  0.676572 -0.985618  0.417501  0.876052 -0.107268 -1.056066 -0.218332
# 4  0.945822 -0.909062  0.667029  1.041938  0.402815 -0.962975 -0.219860
#
#      sp.ent       sfm      mode   meanfun    minfun   modindx  gender
# 0  0.835319 -0.042416  0.207412 -0.837226  0.540973 -0.366495    male
# 1  1.025120  1.077412 -2.141210 -1.247501 -1.089900  0.159773    male
# 2  0.608758  0.670084  0.694611  0.648140  0.567828 -0.761240  female
# 3 -0.515259 -0.533573  0.230766  0.775463  0.602869 -0.112419  female
# 4 -0.715600 -0.588908  0.517069  0.611636  0.652038 -0.295663  female

# %%
from sklearn.ensemble import RandomForestClassifier  
classifier= RandomForestClassifier(n_estimators= 10, criterion="entropy",random_state = 100)  
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=100)

# %%
y_pred= classifier.predict(X_test)

# %%
#Creating the Confusion matrix  
from sklearn.metrics import confusion_matrix  
cm= confusion_matrix(y_test, y_pred)

# %%
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %% [markdown]
# #### incorrect prediction = 6+5 = 11
# #### correct prediction = 317+305 = 622

# %%
print("Accuracy with tree depth  is:", accuracy_score(y_test, y_pred))
print("Precision with tree depth  is:", precision_score(y_test, y_pred))
print("Recall with tree depth  is:", recall_score(y_test, y_pred))
print("F1 Score with tree depth is:", f1_score(y_test, y_pred))
# Out:
# Accuracy with tree depth  is: 0.9826498422712934
# Precision with tree depth  is: 0.9813664596273292
# Recall with tree depth  is: 0.9844236760124611
# F1 Score with tree depth is: 0.9828926905132193

# %%
# chnanging n value to 20
classifier= RandomForestClassifier(n_estimators= 20, criterion="entropy",random_state = 100)  
classifier.fit(X_train, y_train)  
y_pred= classifier.predict(X_test) 
cm= confusion_matrix(y_test, y_pred)  
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
print("Accuracy with tree depth  is:", accuracy_score(y_test, y_pred))
print("Precision with tree depth  is:", precision_score(y_test, y_pred))
print("Recall with tree depth  is:", recall_score(y_test, y_pred))
print("F1 Score with tree depth is:", f1_score(y_test, y_pred))
# Out:
# Accuracy with tree depth  is: 0.9842271293375394
# Precision with tree depth  is: 0.9814241486068112
# Recall with tree depth  is: 0.9875389408099688
# F1 Score with tree depth is: 0.984472049689441

# %%
# chnanging n value  to 40
classifier= RandomForestClassifier(n_estimators= 150, criterion="entropy", random_state = 100)  
classifier.fit(X_train, y_train)  
y_pred= classifier.predict(X_test) 
cm= confusion_matrix(y_test, y_pred)  
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()

# %%
print("Accuracy with tree depth  is:", accuracy_score(y_test, y_pred))
print("Precision with tree depth  is:", precision_score(y_test, y_pred))
print("Recall with tree depth  is:", recall_score(y_test, y_pred))
print("F1 Score with tree depth is:", f1_score(y_test, y_pred))
# Out:
# Accuracy with tree depth  is: 0.9826498422712934
# Precision with tree depth  is: 0.9813664596273292
# Recall with tree depth  is: 0.9844236760124611
# F1 Score with tree depth is: 0.9828926905132193

# %% [markdown]
# # Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier

# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=150, random_state=100)

# Train Adaboost Classifer
model1 = abc.fit(X_train, y_train)


#Predict the response for test dataset
y_pred = model1.predict(X_test)
cm= confusion_matrix(y_test, y_pred)  
fig, ax = plt.subplots(figsize=(7.5, 7.5))
ax.matshow(cm, cmap=plt.cm.Blues, alpha=0.3)
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(x=j, y=i,s=cm[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
print("AdaBoost Classifier Model Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# AdaBoost Classifier Model Accuracy: 0.9794952681388013

# %% [markdown]
# # SVM
